# %% [raw]
# ### Q1. Python Code to Implement the KNN Classifier Algorithm on the Iris Dataset
#
# ```python
# from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.metrics import accuracy_score, classification_report
#
# # Load the dataset
# iris = load_iris()
# X = iris.data
# y = iris.target
#
# # Split the dataset into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# # Create and train the KNN classifier
# knn = KNeighborsClassifier(n_neighbors=5)
# knn.fit(X_train, y_train)
#
# # Make predictions
# y_pred = knn.predict(X_test)
#
# # Evaluate the model
# print("Accuracy:", accuracy_score(y_test, y_pred))
# print("Classification Report:\n", classification_report(y_test, y_pred))
# ```
#
# ### Q2. Python Code to Implement the KNN Regressor Algorithm on the Boston Dataset
#
# ```python
# from sklearn.datasets import load_boston
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.metrics import mean_squared_error, r2_score
#
# # Load the dataset
# boston = load_boston()
# X = boston.data
# y = boston.target
#
# # Split the dataset into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# # Create and train the KNN regressor
# knn_reg = KNeighborsRegressor(n_neighbors=5)
# knn_reg.fit(X_train, y_train)
#
# # Make predictions
# y_pred = knn_reg.predict(X_test)
#
# # Evaluate the model
# print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
# print("R-squared:", r2_score(y_test, y_pred))
# ```
#
# ### Q3. Python Code to Find the Optimal Value of K for the KNN Classifier Using Cross-Validation
#
# ```python
# from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split, GridSearchCV
# from sklearn.neighbors import KNeighborsClassifier
#
# # Load the dataset
# iris = load_iris()
# X = iris.data
# y = iris.target
#
# # Split the dataset into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# # Create a KNN classifier
# knn = KNeighborsClassifier()
#
# # Define the parameter grid
# param_grid = {'n_neighbors': list(range(1, 21))}
#
# # Perform Grid Search with cross-validation
# grid_search = GridSearchCV(knn, param_grid, cv=5)
# grid_search.fit(X_train, y_train)
#
# # Print the best parameters and score
# print("Best K:", grid_search.best_params_['n_neighbors'])
# print("Best Cross-Validation Score:", grid_search.best_score_)
# ```
#
# ### Q4. Implement the KNN Regressor Algorithm with Feature Scaling on the Boston Dataset
#
# ```python
# from sklearn.datasets import load_boston
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import mean_squared_error, r2_score
#
# # Load the dataset
# boston = load_boston()
# X = boston.data
# y = boston.target
#
# # Split the dataset into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# # Standardize the features
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
#
# # Create and train the KNN regressor
# knn_reg = KNeighborsRegressor(n_neighbors=5)
# knn_reg.fit(X_train_scaled, y_train)
#
# # Make predictions
# y_pred = knn_reg.predict(X_test_scaled)
#
# # Evaluate the model
# print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
# print("R-squared:", r2_score(y_test, y_pred))
# ```
#
# ### Q5. Python Code to Implement the KNN Classifier Algorithm with Weighted Voting on the Iris Dataset
#
# ```python
# from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.metrics import accuracy_score, classification_report
#
# # Load the dataset
# iris = load_iris()
# X = iris.data
# y = iris.target
#
# # Split the dataset into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# # Create and train the KNN classifier with weighted voting
# knn = KNeighborsClassifier(n_neighbors=5, weights='distance')
# knn.fit(X_train, y_train)
#
# # Make predictions
# y_pred = knn.predict(X_test)
#
# # Evaluate the model
# print("Accuracy:", accuracy_score(y_test, y_pred))
# print("Classification Report:\n", classification_report(y_test, y_pred))
# ```
#
# ### Q6. Python Function to Standardize the Features Before Applying KNN Classifier
#
# ```python
# from sklearn.preprocessing import StandardScaler
#
# def standardize_features(X_train, X_test):
#     scaler = StandardScaler()
#     X_train_scaled = scaler.fit_transform(X_train)
#     X_test_scaled = scaler.transform(X_test)
#     return X_train_scaled, X_test_scaled
#
# # Example usage:
# # X_train_scaled, X_test_scaled = standardize_features(X_train, X_test)
# ```
#
# ### Q7. Python Function to Calculate the Euclidean Distance Between Two Points
#
# ```python
# import numpy as np
#
# def euclidean_distance(x1, x2):
#     return np.sqrt(np.sum((x1 - x2) ** 2))
#
# # Example usage:
# # distance = euclidean_distance(np.array([1, 2]), np.array([4, 6]))
# ```
#
# ### Q8. Python Function to Calculate the Manhattan Distance Between Two Points
#
# ```python
# import numpy as np
#
# def manhattan_distance(x1, x2):
#     return np.sum(np.abs(x1 - x2))
#
# # Example usage:
# # distance = manhattan_distance(np.array([1, 2]), np.array([4, 6]))
# ```
#
# These code snippets cover a range of tasks related to KNN classification and regression, including implementing the algorithms, tuning hyperparameters, and handling feature scaling.
